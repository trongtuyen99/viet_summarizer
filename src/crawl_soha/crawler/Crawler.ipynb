# %% [markdown]
# ## Crawl 24

# %%
# %cd /content/drive/My Drive/Colab Notebooks/20201/crawler/crawl_news/spiders
# Out:
# /content/drive/My Drive/Colab Notebooks/20201/crawler/crawl_news/spiders

# %%
# !pip install scrapy

# %%
# !scrapy crawl crawler_24h -o news_24h.csv
# Out:
# 2020-10-20 13:46:08 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: crawl_news)
# 2020-10-20 13:46:08 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Jul 17 2020, 12:50:27) - [GCC 8.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.1.1, Platform Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic
# 2020-10-20 13:46:08 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawl_news',
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'crawl_news.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawl_news.spiders']}
# 2020-10-20 13:46:08 [scrapy.extensions.telnet] INFO: Telnet Password: ca5d58d25d5c5ee2
# 2020-10-20 13:46:08 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/20201/crawler/crawl_news/spiders/news_24h.csv")

# %%
#2020-10-20 14:04:14 [scrapy.extensions.feedexport] INFO: Stored csv feed (15558 items) in: news_24h.csv

# %%
# !tar -cvzf news24h_15k_10gb.tar.gz news_24h.csv
# 15558 links
# Out:
# news_24h.csv
# tar: news_24h.csv: file changed as we read it

# %%
# crawl content only, note get all html site
# !scrapy crawl crawler_24h -o news_content_24h.csv
# Out:
# 2020-10-20 14:21:52 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: crawl_news)
# 2020-10-20 14:21:52 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Jul 17 2020, 12:50:27) - [GCC 8.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.1.1, Platform Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic
# 2020-10-20 14:21:52 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawl_news',
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'crawl_news.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawl_news.spiders']}
# 2020-10-20 14:21:52 [scrapy.extensions.telnet] INFO: Telnet Password: c28accbca88cd0f3
# 2020-10-20 14:21:53 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/20201/crawler/crawl_news/spiders/news_content_24h.csv")

# %%
df.iloc[2000]
# Out:
# content                                                  NaN
# news_id                                         -c48a1009253
# sapo       (Trực tiếp bóng đá, Chelsea - PAOK, lượt 5 bản...
# title      Chi tiết Chelsea - PAOK: Morata không chiến th...
# topic                                                Bóng đá
# url        https://www.24h.com.vn/bong-da/truc-tiep-bong-...
# Name: 2000, dtype: object
